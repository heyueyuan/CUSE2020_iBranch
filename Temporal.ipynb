# %%
import pandas as pd
import numpy as np
import math

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
death_df = pd.read_csv('./time_series_2019-ncov-Deaths.csv')
confirmed_df = pd.read_csv('./time_series_2019-ncov-Confirmed.csv')
recovered_df = pd.read_csv('./time_series_2019-ncov-Recovered.csv')

# %%
death_df['Province/State'].values
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu', 'Jiangxi', 'Jilin',
#        'Liaoning', 'Ningxia', 'Qinghai', 'Shaanxi', 'Shandong',
#        'Shanghai', 'Shanxi', 'Sichuan', 'Tianjin', 'Tibet', 'Xinjiang',
#        'Yunnan', 'Zhejiang', 'Hong Kong', 'Macau', 'Taiwan',
#        'Seattle, WA', 'Chicago, IL', 'Tempe, AZ', nan, nan, nan, nan, nan,
#        nan, nan, nan, 'Toronto, ON', 'British Columbia', 'Orange, CA',
#        'Los Angeles, CA', 'New South Wales', 'Victoria', 'Queensland',
#        nan, nan, nan, nan, nan, nan, nan, 'London, ON', nan, nan, nan,
#        nan, 'Santa Clara, CA', nan, 'South Australia', 'Boston, MA',
#        'San Benito, CA', nan, 'Madison, WI',
#        'Diamond Princess cruise ship', 'San Diego County, CA',
#        'San Antonio, TX'], dtype=object)

# %%
death_df['Province/State'].values[0:37]
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu', 'Jiangxi', 'Jilin',
#        'Liaoning', 'Ningxia', 'Qinghai', 'Shaanxi', 'Shandong',
#        'Shanghai', 'Shanxi', 'Sichuan', 'Tianjin', 'Tibet', 'Xinjiang',
#        'Yunnan', 'Zhejiang', 'Hong Kong', 'Macau', 'Taiwan',
#        'Seattle, WA', 'Chicago, IL', 'Tempe, AZ'], dtype=object)

# %%
[i for i in death_df['Province/State'].values if not math.isnan(i)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-1aa1ccc21c48> in <module>
# ----> 1 [i for i in death_df['Province/State'].values if not math.isnan(i)]
#
# <ipython-input-129-1aa1ccc21c48> in <listcomp>(.0)
# ----> 1 [i for i in death_df['Province/State'].values if not math.isnan(i)]
#
# TypeError: must be real number, not str

# %%
def plot_death(country = 'Beijing'):
    x = death_df[death_df['Province/State'] == country].values[0][4:]
    time_series = death_df.columns.values[4:]
    def time_format(date):
        return(date.split(' ')[0].split('/')[0] + \
        '-' + date.split(' ')[0].split('/')[1])
    plot_dot = {}
    plot_dot['date'] = []
    plot_dot['count'] = []
    for i in range(len(x)):
        if math.isnan(x[i]) == False:
            plot_dot['count'].append(int(x[i]))
            plot_dot['date'].append(time_format(time_series[i]))
    plot_df = pd.DataFrame(plot_dot)
    plot_df = plot_df.drop_duplicates()
    return(sns.relplot(x='date', y="count", data=plot_df, height=15, aspect=1))

# %%
def plot_confirmed(country = 'Beijing'):
    x = confirmed_df[confirmed_df['Province/State'] == country].values[0][4:]
    time_series = confirmed_df.columns.values[4:]
    def time_format(date):
        return(date.split(' ')[0].split('/')[0] + \
        '-' + date.split(' ')[0].split('/')[1])
    plot_dot = {}
    plot_dot['date'] = []
    plot_dot['count'] = []
    for i in range(len(x)):
        if math.isnan(x[i]) == False:
            plot_dot['count'].append(int(x[i]))
            plot_dot['date'].append(time_format(time_series[i]))
    plot_df = pd.DataFrame(plot_dot)
    plot_df = plot_df.drop_duplicates()
    sns.relplot(x='date', y="count", data=plot_df, height=15, aspect=1)

# %%
def plot_recovered(country = 'Beijing'):
    x = recovered_df[recovered_df['Province/State'] == country].values[0][4:]
    time_series = recovered_df.columns.values[4:]
    def time_format(date):
        return(date.split(' ')[0].split('/')[0] + \
        '-' + date.split(' ')[0].split('/')[1])
    plot_dot = {}
    plot_dot['date'] = []
    plot_dot['count'] = []
    for i in range(len(x)):
        if math.isnan(x[i]) == False:
            plot_dot['count'].append(int(x[i]))
            plot_dot['date'].append(time_format(time_series[i]))
    plot_df = pd.DataFrame(plot_dot)
    plot_df = plot_df.drop_duplicates()
    sns.relplot(x='date', y="count", data=plot_df, height=15, aspect=1)

# %%
plot_recovered('Anhui')

# %%
plot_confirmed()

# %%
plot_death('Anhui')
